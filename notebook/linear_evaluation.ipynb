# %%
import timm
import torch
import sys

# %%
class Config:
    device='cuda:0'
    batch_size=256
    num_epochs=100
    # num_workers=8,
    lr=3e-4
    weight_decay=0.0008

    dataset_name='cifar10'
    # checkpoint_fn = '/home/hyunseoki/ssd1/02_src/SimpleCLR/runs/Jun26_21-50-22_hyunseoki-ubuntu/checkpoint.pth.tar'
    checkpoint_fn = None

args = Config()

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


def get_stl10_data_loaders(download, shuffle=False, batch_size=args.batch_size):
    train_dataset = datasets.STL10('../data', split='train', download=download,
                                  transform=transforms.ToTensor())

    train_loader = DataLoader(train_dataset, batch_size=batch_size,
                                num_workers=0, drop_last=False, shuffle=shuffle, pin_memory=True)
    
    test_dataset = datasets.STL10('../data', split='test', download=download,
                                    transform=transforms.ToTensor())

    test_loader = DataLoader(test_dataset, batch_size=2*batch_size,
                                num_workers=8, drop_last=False, shuffle=shuffle, pin_memory=True)
    return train_loader, test_loader


def get_cifar10_data_loaders(download, shuffle=False, batch_size=args.batch_size):
    train_dataset = datasets.CIFAR10('../data', train=True, download=download,
                                    transform=transforms.ToTensor())

    train_loader = DataLoader(train_dataset, batch_size=batch_size,
                                num_workers=0, drop_last=False, shuffle=shuffle, pin_memory=True)
    
    test_dataset = datasets.CIFAR10('../data', train=False, download=download,
                                    transform=transforms.ToTensor())

    test_loader = DataLoader(test_dataset, batch_size=2*batch_size,
                                num_workers=8, drop_last=False, shuffle=shuffle, pin_memory=True)
    return train_loader, test_loader


def load_checkpoint(model, fn):
    checkpoint = torch.load(fn)
    state_dict = checkpoint['state_dict']

    for k in list(state_dict.keys()):
        if k.startswith('encoder.'):
            if k.startswith('encoder') and not k.startswith('encoder.fc'):
                state_dict[k[len("encoder."):]] = state_dict[k]
        del state_dict[k]

    log = model.load_state_dict(state_dict, strict=False)
    assert log.missing_keys == ['fc.weight', 'fc.bias']

    print(log)
    return model

# %%
model = timm.create_model(
    'resnet50',
    pretrained=False,
    in_chans=3,
    num_classes=10,
)

if args.checkpoint_fn:
    model = load_checkpoint(model=model, fn=args.checkpoint_fn)

if args.dataset_name == 'cifar10':
    train_loader, test_loader = get_cifar10_data_loaders(download=True)
elif args.dataset_name == 'stl10':
    train_loader, test_loader = get_stl10_data_loaders(download=True)

# freeze all layers but the last fc
# for name, param in model.named_parameters():
#     if name not in ['fc.weight', 'fc.bias']:
#         param.requires_grad = False

# parameters = list(filter(lambda p: p.requires_grad, model.parameters()))
# assert len(parameters) == 2  # fc.weight, fc.bias

optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)
criterion = torch.nn.CrossEntropyLoss().to(args.device)

print("Dataset:", args.dataset_name)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset: cifar10

# %%
epochs = 100
best_top1_acc = 0

for epoch in range(epochs):
    top1_train_accuracy = 0
    for counter, (x_batch, y_batch) in enumerate(train_loader):
      model.train()
      model.to(args.device)
      x_batch = x_batch.to(args.device)
      y_batch = y_batch.to(args.device)

      logits = model(x_batch)
      loss = criterion(logits, y_batch)
      top1 = accuracy(logits, y_batch, topk=(1,))
      top1_train_accuracy += top1[0]

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    top1_train_accuracy /= (counter + 1)
    top1_accuracy = 0
    top5_accuracy = 0

    for counter, (x_batch, y_batch) in enumerate(test_loader):
      model.eval()
      model.to(args.device)
      x_batch = x_batch.to(args.device)
      y_batch = y_batch.to(args.device)

      logits = model(x_batch)

      top1, top5 = accuracy(logits, y_batch, topk=(1,5))
      top1_accuracy += top1[0]
      top5_accuracy += top5[0]
    
    top1_accuracy /= (counter + 1)
    top5_accuracy /= (counter + 1)

    if top1_accuracy > best_top1_acc:
       best_top1_acc = top1_accuracy
    print(f"Epoch {epoch} Top1 Train accuracy {top1_train_accuracy.item()}\tTop1 Test accuracy: {top1_accuracy.item()}\tTop5 test acc: {top5_accuracy.item()}")

print(f'best top1_acc {best_top1_acc}')
# Out:
# Epoch 0 Top1 Train accuracy 36.07262420654297	Top1 Test accuracy: 45.37913513183594	Top5 test acc: 89.90694427490234
# Epoch 1 Top1 Train accuracy 57.05755615234375	Top1 Test accuracy: 51.038028717041016	Top5 test acc: 93.56100463867188
# Epoch 2 Top1 Train accuracy 66.85746002197266	Top1 Test accuracy: 56.01447677612305	Top5 test acc: 95.43370819091797
# Epoch 3 Top1 Train accuracy 74.41645050048828	Top1 Test accuracy: 56.3884391784668	Top5 test acc: 94.384765625
# Epoch 4 Top1 Train accuracy 79.15856170654297	Top1 Test accuracy: 46.540672302246094	Top5 test acc: 90.4566879272461
# Epoch 5 Top1 Train accuracy 81.86104583740234	Top1 Test accuracy: 56.78022003173828	Top5 test acc: 93.2887191772461
# Epoch 6 Top1 Train accuracy 85.34518432617188	Top1 Test accuracy: 61.865234375	Top5 test acc: 95.72438049316406
# Epoch 7 Top1 Train accuracy 88.16246795654297	Top1 Test accuracy: 60.66176986694336	Top5 test acc: 95.23092651367188
# Epoch 8 Top1 Train accuracy 90.31807708740234	Top1 Test accuracy: 60.491729736328125	Top5 test acc: 94.86213684082031
# Epoch 9 Top1 Train accuracy 92.55300903320312	Top1 Test accuracy: 58.046302795410156	Top5 test acc: 92.87683868408203
# Epoch 10 Top1 Train accuracy 94.12348175048828	Top1 Test accuracy: 64.81732940673828	Top5 test acc: 96.20404815673828
# Epoch 11 Top1 Train accuracy 95.05859375	Top1 Test accuracy: 65.41072845458984	Top5 test acc: 96.06502532958984
# Epoch 12 Top1 Train accuracy 95.50940704345703	Top1 Test accuracy: 63.99471664428711	Top5 test acc: 96.47403717041016
# Epoch 13 Top1 Train accuracy 96.07182312011719	Top1 Test accuracy: 64.80583953857422	Top5 test acc: 95.91682434082031
# Epoch 14 Top1 Train accuracy 96.589599609375	Top1 Test accuracy: 65.03331756591797	Top5 test acc: 95.7301254272461
# Epoch 15 Top1 Train accuracy 96.83673095703125	Top1 Test accuracy: 64.32329559326172	Top5 test acc: 96.064453125
# Epoch 16 Top1 Train accuracy 97.10538482666016	Top1 Test accuracy: 65.888671875	Top5 test acc: 96.21725463867188
# Epoch 17 Top1 Train accuracy 97.35889434814453	Top1 Test accuracy: 66.13970184326172	Top5 test acc: 96.15751647949219
# Epoch 18 Top1 Train accuracy 97.37882232666016	Top1 Test accuracy: 66.51998901367188	Top5 test acc: 96.33961486816406
# Epoch 19 Top1 Train accuracy 97.35929107666016	Top1 Test accuracy: 68.43922424316406	Top5 test acc: 96.37236022949219
# Epoch 20 Top1 Train accuracy 97.39675903320312	Top1 Test accuracy: 62.9509391784668	Top5 test acc: 94.74034881591797
# Epoch 21 Top1 Train accuracy 97.56855773925781	Top1 Test accuracy: 66.20174407958984	Top5 test acc: 95.85765838623047
# Epoch 22 Top1 Train accuracy 97.66621398925781	Top1 Test accuracy: 64.67658996582031	Top5 test acc: 94.30549621582031
# Epoch 23 Top1 Train accuracy 97.51435089111328	Top1 Test accuracy: 65.439453125	Top5 test acc: 95.31652069091797
# Epoch 24 Top1 Train accuracy 97.5	Top1 Test accuracy: 67.59822845458984	Top5 test acc: 96.21955871582031
# Epoch 25 Top1 Train accuracy 97.70966339111328	Top1 Test accuracy: 66.42635345458984	Top5 test acc: 95.67498016357422
# Epoch 26 Top1 Train accuracy 97.77901458740234	Top1 Test accuracy: 66.93187713623047	Top5 test acc: 94.9534683227539
# Epoch 27 Top1 Train accuracy 97.69172668457031	Top1 Test accuracy: 64.5484848022461	Top5 test acc: 94.2503433227539
# Epoch 28 Top1 Train accuracy 97.61638641357422	Top1 Test accuracy: 64.92761993408203	Top5 test acc: 95.2734375
# Epoch 29 Top1 Train accuracy 98.01817321777344	Top1 Test accuracy: 68.447265625	Top5 test acc: 96.39820861816406
# Epoch 30 Top1 Train accuracy 97.65824127197266	Top1 Test accuracy: 65.40096282958984	Top5 test acc: 95.85363006591797
# Epoch 31 Top1 Train accuracy 97.84717559814453	Top1 Test accuracy: 65.57445526123047	Top5 test acc: 94.84490203857422
# Epoch 32 Top1 Train accuracy 97.82764434814453	Top1 Test accuracy: 65.59053802490234	Top5 test acc: 94.86788177490234
# Epoch 33 Top1 Train accuracy 97.99066925048828	Top1 Test accuracy: 63.2732048034668	Top5 test acc: 94.20553588867188
# Epoch 34 Top1 Train accuracy 97.89102172851562	Top1 Test accuracy: 66.67049407958984	Top5 test acc: 94.87936401367188
# Epoch 35 Top1 Train accuracy 98.07278442382812	Top1 Test accuracy: 67.45404815673828	Top5 test acc: 95.10857391357422
# Epoch 36 Top1 Train accuracy 97.87068939208984	Top1 Test accuracy: 69.61225128173828	Top5 test acc: 96.40165710449219
# Epoch 37 Top1 Train accuracy 97.81768035888672	Top1 Test accuracy: 67.3023910522461	Top5 test acc: 95.78125
# Epoch 38 Top1 Train accuracy 98.17243194580078	Top1 Test accuracy: 66.90889739990234	Top5 test acc: 95.71174621582031
# Epoch 39 Top1 Train accuracy 98.02455139160156	Top1 Test accuracy: 68.291015625	Top5 test acc: 96.03401184082031
# Epoch 40 Top1 Train accuracy 97.98070526123047	Top1 Test accuracy: 67.48334503173828	Top5 test acc: 95.0120620727539
# Epoch 41 Top1 Train accuracy 98.04248809814453	Top1 Test accuracy: 67.0875473022461	Top5 test acc: 95.8180160522461
# Epoch 42 Top1 Train accuracy 97.97273254394531	Top1 Test accuracy: 66.74919891357422	Top5 test acc: 95.22978210449219
# Epoch 43 Top1 Train accuracy 98.2421875	Top1 Test accuracy: 68.53170776367188	Top5 test acc: 95.49459838867188
# Epoch 44 Top1 Train accuracy 98.2995834350586	Top1 Test accuracy: 68.44438934326172	Top5 test acc: 95.46530151367188
# Epoch 45 Top1 Train accuracy 97.97312927246094	Top1 Test accuracy: 68.92118835449219	Top5 test acc: 95.66521453857422
# Epoch 46 Top1 Train accuracy 98.18160247802734	Top1 Test accuracy: 67.5999526977539	Top5 test acc: 95.92198944091797
# Epoch 47 Top1 Train accuracy 98.21508026123047	Top1 Test accuracy: 69.1090316772461	Top5 test acc: 95.84386444091797
# Epoch 48 Top1 Train accuracy 98.27806091308594	Top1 Test accuracy: 66.64694213867188	Top5 test acc: 94.61799621582031
# Epoch 49 Top1 Train accuracy 98.34382629394531	Top1 Test accuracy: 65.029296875	Top5 test acc: 94.24459838867188
# Epoch 50 Top1 Train accuracy 98.14652252197266	Top1 Test accuracy: 67.7613754272461	Top5 test acc: 95.28780364990234
# Epoch 51 Top1 Train accuracy 98.1202163696289	Top1 Test accuracy: 69.92244720458984	Top5 test acc: 96.04779815673828
# Epoch 52 Top1 Train accuracy 98.29998016357422	Top1 Test accuracy: 69.43991088867188	Top5 test acc: 95.92658996582031
# Epoch 53 Top1 Train accuracy 98.29200744628906	Top1 Test accuracy: 68.40648651123047	Top5 test acc: 96.28102111816406
# Epoch 54 Top1 Train accuracy 98.30397033691406	Top1 Test accuracy: 70.14016723632812	Top5 test acc: 95.57272338867188
# Epoch 55 Top1 Train accuracy 98.17601776123047	Top1 Test accuracy: 69.83341217041016	Top5 test acc: 95.94381713867188
# Epoch 56 Top1 Train accuracy 98.31393432617188	Top1 Test accuracy: 70.400390625	Top5 test acc: 96.37638092041016
# Epoch 57 Top1 Train accuracy 98.32350158691406	Top1 Test accuracy: 67.47013092041016	Top5 test acc: 95.76344299316406
# Epoch 58 Top1 Train accuracy 98.30596160888672	Top1 Test accuracy: 68.7229995727539	Top5 test acc: 96.22013092041016
# Epoch 59 Top1 Train accuracy 98.29798889160156	Top1 Test accuracy: 69.78227996826172	Top5 test acc: 95.91739654541016
# Epoch 60 Top1 Train accuracy 98.37133026123047	Top1 Test accuracy: 69.96266174316406	Top5 test acc: 96.04549407958984
# Epoch 61 Top1 Train accuracy 98.359375	Top1 Test accuracy: 67.9808120727539	Top5 test acc: 95.71920776367188
# Epoch 62 Top1 Train accuracy 98.42753601074219	Top1 Test accuracy: 68.97001647949219	Top5 test acc: 95.1953125
# Epoch 63 Top1 Train accuracy 98.50885009765625	Top1 Test accuracy: 68.54549407958984	Top5 test acc: 95.54113006591797
# Epoch 64 Top1 Train accuracy 98.25972747802734	Top1 Test accuracy: 70.01321411132812	Top5 test acc: 96.30859375
# Epoch 65 Top1 Train accuracy 98.32549285888672	Top1 Test accuracy: 68.81376647949219	Top5 test acc: 95.42797088623047
# Epoch 66 Top1 Train accuracy 98.50525665283203	Top1 Test accuracy: 69.96553802490234	Top5 test acc: 96.14659881591797
# Epoch 67 Top1 Train accuracy 98.26729583740234	Top1 Test accuracy: 69.80181121826172	Top5 test acc: 96.32008361816406
# Epoch 68 Top1 Train accuracy 98.46898651123047	Top1 Test accuracy: 69.48529815673828	Top5 test acc: 96.14086151123047
# Epoch 69 Top1 Train accuracy 98.4753646850586	Top1 Test accuracy: 68.2887191772461	Top5 test acc: 95.3929214477539
# Epoch 70 Top1 Train accuracy 98.3936538696289	Top1 Test accuracy: 69.53125	Top5 test acc: 95.97771453857422
# Epoch 71 Top1 Train accuracy 98.39285278320312	Top1 Test accuracy: 66.59294891357422	Top5 test acc: 95.9156723022461
# Epoch 72 Top1 Train accuracy 98.39564514160156	Top1 Test accuracy: 67.93370819091797	Top5 test acc: 95.5394058227539
# Epoch 73 Top1 Train accuracy 98.64476776123047	Top1 Test accuracy: 70.12407684326172	Top5 test acc: 95.791015625
# Epoch 74 Top1 Train accuracy 98.49529266357422	Top1 Test accuracy: 70.94841766357422	Top5 test acc: 96.02424621582031
# Epoch 75 Top1 Train accuracy 98.40082550048828	Top1 Test accuracy: 69.98104095458984	Top5 test acc: 95.88522338867188
# Epoch 76 Top1 Train accuracy 98.37372589111328	Top1 Test accuracy: 70.01781463623047	Top5 test acc: 95.98058319091797
# Epoch 77 Top1 Train accuracy 98.51322937011719	Top1 Test accuracy: 69.8265151977539	Top5 test acc: 96.19715118408203
# Epoch 78 Top1 Train accuracy 98.5985336303711	Top1 Test accuracy: 68.3812026977539	Top5 test acc: 95.63304901123047
# Epoch 79 Top1 Train accuracy 98.43350982666016	Top1 Test accuracy: 69.18256378173828	Top5 test acc: 95.70198059082031
# Epoch 80 Top1 Train accuracy 98.43311309814453	Top1 Test accuracy: 70.44405364990234	Top5 test acc: 95.77780151367188
# Epoch 81 Top1 Train accuracy 98.57660675048828	Top1 Test accuracy: 70.56238555908203	Top5 test acc: 96.47633361816406
# Epoch 82 Top1 Train accuracy 98.64078521728516	Top1 Test accuracy: 70.77837371826172	Top5 test acc: 95.52102661132812
# Epoch 83 Top1 Train accuracy 98.5048599243164	Top1 Test accuracy: 70.97139739990234	Top5 test acc: 96.12821960449219
# Epoch 84 Top1 Train accuracy 98.36495208740234	Top1 Test accuracy: 70.85994720458984	Top5 test acc: 96.33846282958984
# Epoch 85 Top1 Train accuracy 98.38249206542969	Top1 Test accuracy: 71.41199493408203	Top5 test acc: 96.21782684326172
# Epoch 86 Top1 Train accuracy 98.55229187011719	Top1 Test accuracy: 71.13338470458984	Top5 test acc: 96.34076690673828
# Epoch 87 Top1 Train accuracy 98.64875793457031	Top1 Test accuracy: 71.01677703857422	Top5 test acc: 96.29193878173828
# Epoch 88 Top1 Train accuracy 98.45742797851562	Top1 Test accuracy: 68.9625473022461	Top5 test acc: 95.1344223022461
# Epoch 89 Top1 Train accuracy 98.60092163085938	Top1 Test accuracy: 70.91107940673828	Top5 test acc: 96.32123565673828
# Epoch 90 Top1 Train accuracy 98.47735595703125	Top1 Test accuracy: 69.74781799316406	Top5 test acc: 95.98805236816406
# Epoch 91 Top1 Train accuracy 98.58697509765625	Top1 Test accuracy: 69.83858489990234	Top5 test acc: 95.84444427490234
# Epoch 92 Top1 Train accuracy 98.58577728271484	Top1 Test accuracy: 71.3551254272461	Top5 test acc: 95.93922424316406
# Epoch 93 Top1 Train accuracy 98.54671478271484	Top1 Test accuracy: 70.68416595458984	Top5 test acc: 96.0328598022461
# Epoch 94 Top1 Train accuracy 98.62483978271484	Top1 Test accuracy: 70.79676055908203	Top5 test acc: 96.19657897949219
# Epoch 95 Top1 Train accuracy 98.67266845703125	Top1 Test accuracy: 71.73828125	Top5 test acc: 96.43611907958984
# Epoch 96 Top1 Train accuracy 98.70416259765625	Top1 Test accuracy: 69.07054901123047	Top5 test acc: 96.02826690673828
# Epoch 97 Top1 Train accuracy 98.59893035888672	Top1 Test accuracy: 68.30480194091797	Top5 test acc: 94.9925308227539
# Epoch 98 Top1 Train accuracy 98.38966369628906	Top1 Test accuracy: 71.23506927490234	Top5 test acc: 96.21150970458984
# Epoch 99 Top1 Train accuracy 98.71013641357422	Top1 Test accuracy: 71.69290161132812	Top5 test acc: 96.05986022949219
# best top1_acc 71.73828125
